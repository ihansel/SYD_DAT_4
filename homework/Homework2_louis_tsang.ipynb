# %% [markdown]
# # SYD DAT 4 Lab 2 - Visualisation and Regression
#
# ##Homework - Due 29th April 2016
#
# #### Setup
# * Signup for an AWS account
#     - DONE - send Ian/Matt details
#
# #### Communication
# * Imagine you are trying to explain to someone what Linear Regression is - but they have no programming/maths experience? How would you explain the overall process, what a p-value means and what R-Squared means?
#     - DONE -
# **Linear Regression**
# 1) Linear Regression is a mathematical/statistic technique for modelling the relationship between a dependent variable (often denoted as Y) and a single or multiple independent variables (often denoted as Xs).
# 2) The simpliest form of Linear Regression is as follows: Y = a + bX + E where Y is the variable we are trying to predict (the dependent variable), X is the varaible we are trying to predict Y with, a is the intercept of the straight line we are fitting, b is the slope and E is the residues or error term of the line fitting. In this case, we are trying to form a relationship between Xs and Ys. The a/b denote the "characteristics" of the straight line relationship we are fitten between X and Y. An example of simple regression could be we are trying to find the relationship or predict seawater temperature (Y) by looking at current air temerpature (X).
# 3) Multiple linear regression is an extension of the above but we introduce many Xs. This takes the form: Y = a + b1X1 + b2X2 + ... + bnXn + E. Any example of multiple regression could be we are trying to find the relationship or predict seawater temperature (Y) by looking at a number of factors such as current air temerpature (X1), amount of sunlight (X2), wind speed (X3) etc...
# 4) To arrive at the values of a(s) and b(s), linear regression uses a "least squares" approach. In short, if we were to use simple regression as an example, the technique attempts to draw a straight line through the scatterplot (where x-axis is the predictor variable and y-axis is the predicted variable) and determines the "best" fit by minimising the square of the difference of the observed value and the fitted (drawn straight line) value. The square is used to cater for negative numbers.
# **p-value**
# 1) In statistics p-value is used to determine the significance of a statistical test. In relation to linear regression, the hypothesis test we are performing is whether the coefficient (b) of the predictor variable is zero. A low p-value indicates that you can reject the null hypothesis. This means the predictor variable (X) used for fitting is likely to add value to the linear regression model because changes in Y is likely due to X.
# 2) The "level" at which you determine whether a p-value is low or not can be disputed. 0.05 is the norm for most statistical tests. Tests requiring more vigor demand significance at a 0.01 level or less, while some data investigation work can accept 0.1 if it is used for exploratory purposes only.
# **R-squared**
# 1) R-square is a descriptive statistic used in regression to help the modeller gauge the "fit" of the model (but it is not the only one!)
# 2) R-square describes the amount of variance the fitted model can account for. The higher the r-square, the better fit the model. R-square can take values between 0 and 1. While a higher r-square is desired, evaluation of the model should be done not just on r-square.
#
# > Really good overview. Nice examples and very clear explanations. I like how you tied it to an actual use case.
#
# * Read the paper [Useful things to know about machine learning]( https://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf).
#     * What have we covered so far from this paper?
# 1) Some modelling techniques which form the basis of the "Representation" phase of machine learning.
# 2) Understand the concept and purpose of building a model - to generalise relationships from variables to a predicted observation so we can make predictions.
# 3) When building a model, we need to be careful not to overfit. Training/hold-out data can help reduct the instances of overfitting.
# 4) We need to understand variance and bias and they role they play in determining what is an appropriate model for use.
#
# > Great, if the connection between what we've covered and how it's written in the paper isn't clear please let me know. Nice succinct overview
#
#     * Explain sections 6-13 in your own words*
# *Section 6*
#      - Human processing struggles with higher dimension thinking (i.e. thinking that involves more than 3 dimensions, in our case, e.g. a dataset with 4 or more variables and we try to form relationships within/between them in our heads).
#      - For example, a Scatterplot can show us nicely how two variables are related to each other. A 3D scatterplot can help us visually depict 3 dimensions and how 3 variables interact with each other. Clever grouping and colour in a 3D scatterplot can probably even depict 4 or 5 dimensions.
#      - However, anymore relationships are no longer "easy" to spot and can even be incorrect due to how variables can interact with each other. Interaction effects and correlations need ot be taken into account when doing data analyses on a dataset with many variables.
#
# > Nice summary, higher dimensionalities are hard for us to understand properly.
#
# *Section 7*
#     - Noise in data and data quality issues mean theoretical concepts do not hold practical truth.
#
# > Yes, you still need to validate a theory when you apply it in practice.
#
# *Section 8*
#     - Automated data processing is key in machine learning. The better this step is, the more efficient and accurate models/insights can be generated.
#
# > Yes, nicely put. This is one of the reasons deep learning is an area of interest right now - it is seen as almost automatically generating features in the data.
#
# *Section 9*
#     - Data, Data, Data...you cannot build bricks without clay.
#     - More data makes your model more robust and increase the validity of your result.
#     - More data allows for more validation to be performed (e.g better usage of your training/holding sample)
#
# > Excellent takeaways and well put
#
# *Section 10*
#     - There is no one-size-fits-all model.
#     - Different modelling techniques will have differing weakness. The assumptions that are required should not be violated as the model loses meaning and any mathematical validity.
#
# > Yes, combining lots of weak learners can give you a good result. Combining complimentary models is a great way to get an accurate model.
#
# *Section 11*
#     - Simple model has its advantages (e.g easily communicated, reduce risk of over-fitting)
#     - However, modelling technique complexities are often necessary and the user needs to understand the trade-off between simplicity and accuracy
#
# > Yes, this is one of the reasons XGBOOST is getting a lot of attention right now.
#
# *Section 13*
#     - Correlation between two variables does not mean one causes the other (e.g. when the titanic sank, people were drinking a lot of coffee, but that doesnt mean drinking coffee will sink the titanic. If anything they were drinking coffee because it was cold!!)
#     - Correlation helps with data investigation as it can assist in selecting variables.
#
# > Excellent, causation is a very difficult thing to prove without proper experimental design.
#
# #### Machine Learning
# * Read chapters 3 and 6 of Introduction to Statistical Learning
#     - DONE -
# * Describe 3 ways we can select what features to use in a model
# 1) Correlation Matrix - helps determine if variables need to be removed before any modelling technique is used.
# 2) P-value - you want to ensure the variable selected has a statistically significant coefficient.
# 3) Coefficient sign - you want to ensure the relationship between the input variable and output variable makes intuitive sense
#
# > Yes, I would also add, stepwise regression, regularised regression (Lasso, Rigde, Elastic Net, etc) and PCA regression. If any of these aren't clear let me know.
#
# * Complete the first 3 exercises from Chapter 3 in Python
# **Question 1**
# The null hypothesis of the p-values is that the coefficient of the predictor variables are zero. Testing for the null hypothesis hopes to reject this (i.e. rejecting it means the variable coefficient is significant and can add value to our model).
#
# In this example, TV and Radio are both considered significant. That is because the p-value are less than 0.05, meaning we have evidence to reject the null hypothesis of zero coefficients. In the context of the regression analyses, it shows that spend on TV and Radio can potentially increase sales.
#
# Newspaper however tells a different story. The p-value is greater than 0.05 meaning we do not have enough evidence to reject the null hypothesis. The variable is not significant (i.e. there is no evidence to suggest that spending more on newspaper would increase sales). Inspecting the coefficient of the newspaper variable is interesting, as the negative sign indiciated that the more you spend on newspaper, the less sales you'll be expected to recieve!!!
#
# > Excellent explanation, well put in terms of the original analysis and framed to answer the business quesiton - great work!!!
#
# **Question 2**
# KNN Classificiation takes a point, and computes the distance between it and all other training points. Based on the value of K, the point takes class of the majority of the K nearest points.
#
# KNN regression you are trying to predict Ys. Compute the K nearest neighbours and average those Ys (as opposed to taking the majority) to recieve your "predicted" Y value. K-NN methods are relatively good for interpolation but rather poor for exterpolation.
#
# > Correct
#
# **Question 3**
# Suppose we have a data set with five predictors,
# X1 = GPA,
# X2 = IQ,
# X3 = Gender (1 for Female and 0 for Male),
# X4 = Interaction between GPA and IQ, and
# X5 = Interaction between GPA and Gender.
# The response is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get
# βˆ0 = 50,
# βˆ1 = 20,
# βˆ2 = 0.07,
# βˆ3 = 35,
# βˆ4 = 0.01,
# βˆ5 = −10
# (a) Which answer is correct, and why?
# i. For a fixed value of IQ and GPA, males earn more on average than females.
#     - No, females earn more -
# ii. For a fixed value of IQ and GPA, females earn more on average than males.
#     - No, presence of an interaction effect means it is not simply the case that females earn more -
# iii. For a fixed value of IQ and GPA, males earn more on average than females provided that the GPA is high enough.
#     - Yes. The interaction effect variable X5 has a negative coefficient. This means at first, because of X3, females earn more, but as GPA increases - the term B5 and X5 will overtake females
# iv. For a fixed value of IQ and GPA, females earn more on average than males provided that the GPA is high enough.
#     - No. because of the reason above -
#
# > Correct and excellently explained.
#
# (b) Predict the salary of a female with IQ of 110 and a GPA of 4.0.
#
# 50 + 20X4.0 + 0.07X110 + 35X1 + 0.01*4.0*110 + (-10)*4.0*1 = 137.1
# **this seems high - i'm a little confused....??**
#
# > CORRECT
#
# (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.
#     - Not necessarily. IQ is on a different scale to GPA so unless the coefficients are standardised, we cannot make the assessment that this interaction effect is weaker than the GPA/gender interaction effect.-
#
# > CORRECT, the answer is false. We need to examine the associated p-value as well because it may not be significant.
#
# #### Course Project
# * For the following setup a new github repository for your project and share it with Matt and Ian over Slack.
#     - DONE -
#     https://github.com/louistsang86/Project_MMA.git
# * Load the data you have gathered for your project into Python and run some summary statistics over the data. Are there any interesting features of the data that jump out? (Include the code)
#     - See below -
# * Draft/Sketch on paper (or wireframe) some data visualisations that would be useful for you to explore your data set
#     - See below -
# * Are there any regresion or clustering techniques you could use in your project? Write them down (with the corresponding scikit learn function) and what you think you would get out of it.
#     - See below -
#
# > Excellent work Louis, The homework is well written and the project is going really well. Great progress - keep it up!!!
#
# **Instructions: copy this file and append your name in the filename, e.g. Homework2_ian_hansel.ipynb.
# Then commit this in your local repository, push it to your github account and create a pull request so I can see your work. Remeber if you get stuck to look at the slides going over Fork, Clone, Commit, Push and Pull request.**

# %% [markdown]
# #Project - Initial Data Analyses#
# **Data**
# I currently have 3 main data files/sets.
# (1) List of all professional MMA fighters from all organisations in history from fight metrics.
# (2) List of all professional MMA fighters on contract with the UFC (one of the leading/biggest MMA leagues in the world)
# (3) List of all UFC fight schedules, including who are the fighters, who won and by which method etc...
#
# I will need to investigate if I can get some odds/betting data as well. May make the output of the modelling interesting.

# %%
#Looking at file (1), I want to do a few scatter plots to see if the data "looks" manageable.
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
plt.style.use('ggplot') # This styles the graphs in a nicer format

#Load and inspect some data - this csv sourced from fight metrics has some information about all MMA fighters
ALL_FIGHTERS = pd.read_csv('../../Project/Idea 1 - MMA/CSV Datasets/Fight Metric - ALL MMA FIGHTERS.csv')
ALL_FIGHTERS.shape
#2734 observations, each denoting an individual fighter.
# Out:
# (2734, 20)

# %%
#Inspection of the first few rows show soft characteristics of fighters such as height, weight and reach.
ALL_FIGHTERS.head(5)
ALL_FIGHTERS.describe()
# Out:
#          Height_FT  Height_INCH    Height_CM    WEIGHT_LB    WEIGHT_KG  \
# count  2474.000000  2474.000000  2474.000000  2659.000000  2659.000000
# mean      5.403800     5.675829   179.124414   176.562994    80.087561
# std       0.492403     3.855876     8.453960    40.500640    18.370766
# min       5.000000     0.000000   154.940000   105.000000    47.627160
# 25%       5.000000     2.000000   172.720000   154.000000    69.853168
# 50%       5.000000     6.000000   180.340000   170.000000    77.110640
# 75%       6.000000     9.000000   185.420000   195.000000    88.450440
# max       7.000000    11.000000   226.060000   770.000000   349.265840
#
#         REACH_INCH            W            L            D  BELT
# count  1105.000000  2734.000000  2734.000000  2733.000000     0
# mean     71.857014    11.299561     5.245794     0.310282   NaN
# std       4.002876     9.211656     4.852709     0.916915   NaN
# min      60.000000     0.000000     0.000000     0.000000   NaN
# 25%      69.000000     5.000000     2.000000     0.000000   NaN
# 50%      72.000000    10.000000     4.000000     0.000000   NaN
# 75%      75.000000    15.000000     7.000000     0.000000   NaN
# max      84.000000   127.000000    74.000000    11.000000   NaN

# %%
#Since 2000, fighters fight in specific weight divisions. Lets analyse and look for any trends/patterns within each weight class
#first, let's look at males
MALE_FIGHTERS = ALL_FIGHTERS[ALL_FIGHTERS.GENDER=='M']
MALE_FIGHTERS.shape
#2624 fighters are male
MALE_FIGHTERS.DIVISION.value_counts().plot(kind='bar', title='Count by DIVISION')
plt.xlabel('DIVISION')
plt.ylabel('Count')
plt.show()

# %%
#Let's have a look at a division level, the win ratios. 
#We are going to define the win ratio as total number of WINs/Total Number of Fights by the fighter
MALE_FIGHTERS.loc[:,('TOTAL_FIGHTS')] = (MALE_FIGHTERS.loc[:,('W')] + MALE_FIGHTERS.loc[:,('D')] + MALE_FIGHTERS.loc[:,('L')])
MALE_FIGHTERS.loc[:,('WIN_RATIO')] = MALE_FIGHTERS.loc[:,('W')] / MALE_FIGHTERS.loc[:,('TOTAL_FIGHTS')]
MALE_FIGHTERS.head(5)
# Out:
# /Users/LouisTsang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/LouisTsang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#          Full Name  FIRST       LAST       NICKNAME    HT.  Height_FT  \
# 0      Aaron Brink  Aaron      Brink            NaN  6' 3"          6
# 1        Aaron Ely  Aaron        Ely     The Cyborg  5' 8"          5
# 2  Aaron Lanfranco  Aaron  Lanfranco            NaN    NaN        NaN
# 3     Aaron Miller  Aaron     Miller  Blood Spiller  5' 9"          5
# 4   Aaron Phillips  Aaron   Phillips      The Model  5' 9"          5
#
#    Height_INCH  Height_CM       WT.  WEIGHT_LB    ...     REACH_INCH  \
# 0            3     190.50  205 lbs.        205    ...            NaN
# 1            8     172.72  135 lbs.        135    ...            NaN
# 2          NaN        NaN  155 lbs.        155    ...            NaN
# 3            9     175.26  145 lbs.        145    ...            NaN
# 4            9     175.26  135 lbs.        135    ...             70
#
#      STANCE   W   L  D  BELT  GENDER           DIVISION TOTAL_FIGHTS WIN_RATIO
# 0  Orthodox  25  21  0   NaN       M  Light Heavyweight           46  0.543478
# 1       n/a   5   2  0   NaN       M       Bantamweight            7  0.714286
# 2       n/a   5   1  0   NaN       M        Lightweight            6  0.833333
# 3       n/a  14  10  0   NaN       M      Featherweight           24  0.583333
# 4  Southpaw   8   2  0   NaN       M       Bantamweight           10  0.800000
#
# [5 rows x 22 columns]

# %%
#first look at all fighters
groups = MALE_FIGHTERS.groupby('DIVISION')
colors = pd.tools.plotting._get_standard_colors(len(groups), color_type='random')
MALE_FIGHTERS.plot(kind='scatter',x='TOTAL_FIGHTS',y='WIN_RATIO',title='Win Ratio Scatter',c=colors)

# %%
#Looking at File (3), I want to see if there is any insights I can draw quickly from the fight schedule data
FIGHTS = pd.read_csv('../../Project/Idea 1 - MMA/CSV Datasets/ALL UFC FIGHTS 2-23-2016 SHERDOG.COM.csv')
FIGHTS.method.value_counts().plot(kind='bar', title='Count by Method')

#Substantially more Decision fights compared to other methods of finishing. Perhaps it'll be interesting not to model "Win"
#as an outcome but also the method

# %%
FIGHTS.groupby('method').round.mean().plot(kind='bar')
plt.ylabel('Average Round for each Method')
#Not sure if I can draw insights from this yet...

# %%
FIGHTS_SUBONLY = FIGHTS[FIGHTS.method=='Submission']
FIGHTS_SUBONLY.method_d.value_counts().plot(kind='bar', title='Count by Method - Submission Only')
plt.xlabel('Submission Type')
plt.ylabel('Count')
#no surprise RNC and triangles are the most popular but I am surprised lack of leg lock finishes...
#maybe i should practice those more :)

# %%
FIGHTS_SUBONLY = FIGHTS[FIGHTS.method=='Submission']
FIGHTS_SUBONLY.groupby('method_d').round.mean().plot(kind='bar')
plt.ylabel('Average Round for each Method')
