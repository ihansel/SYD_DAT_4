# %% [markdown]
# # SYD DAT 4 Lab 1 - Git and Markdown
#
# ## Homework:
#
# #### Setup
# * Resolve any installation issues before next class.
# * Make sure you have a github profile and created a repo called "SYD_DAT_4"
# * Clone the class repo (this one!)
# > [nakatas/SYD_DAT_4](https://github.com/nakatas/SYD_DAT_4.git)
# * Review this [code](../labs/Week 1/00_python_refresher.py) for a recap of some Python basics.
#
# #### Communication
# * Read [Analyzing the Analyzers](http://cdn.oreillystatic.com/oreilly/radarreport/0636920029014/Analyzing_the_Analyzers.pdf) for a useful look at the different types of data scientists. Write down 5 key points you took away from the article
# > 1. The most successful data scientists are those with substantial, deep expertise in at least one aspect of data science, be it statistics, big data, or business communication.
# >
# > 2. T-shaped skills : "T" represents breadth of skills, across the top, with depth in one area represented by the vertical bar.
# >
# > 3. The variety of Data Scientist : Data Businesspeople, Data Creatives, Data Developer, Data Researchers
# >
# >> * Data Developer: Developer, Engineer
# >
# >> * Data Researcher: Researcher , Scientist, Statistician
# >
# >> * Data Creative: Jack of All Trades, Artist, Hacker
# >
# >> * Data Businessperson: Leader, Businesperson, Entreperneur
#
# > It's great that you wrote a bit about the T shape, it's really important to have some knowledge of all those fields and choosing which field you want to specialise in.
#
# * Read about some [Markdown Techniques](http://daringfireball.net/projects/markdown/syntax)
#
# > It's clear by how you've laid out the homework you've read the book - great work !
#
# * Write a summary of 2 chapters of [The Data Science Handbook](http://www.thedatasciencehandbook.com/) in Markdown and submit a pull request in the Lab Directory
# > <p>1. RILEY NEWMAN Head of Data at Airbnb</p>
# > <pre><code>more data beats better models; better data beats more data; and the 80/20 rule.
# > </code></pre>
#
# >> AirBNB have a great data science team and are writing some really interesting work up about this at the moment. Check out https://medium.com/airbnb-engineering if you want to see more of their work - highly recommended.
#
#
# > <p>2. DREW CONWAY Head of Data at Project Florida</p>
# > <pre><code>he drew up his famous Data Science Venn Diagram.
# > </code></pre>
# > ![alt text](http://static1.squarespace.com/static/5150aec6e4b0e340ec52710a/t/51525c33e4b0b3e0d10f77ab/1364352052403/Data_Science_VD.png)
#
# > It's a simple description but it does a good job at explaining the different components
#
# #### Programming
# * Complete the lab from class and the additional Exercise below
# > [nakatas/SYD_DAT_4/labs/Week 1/](https://github.com/nakatas/SYD_DAT_4/blob/master/labs/Week%201/Lab%201%20-%20Pandas.ipynb)
#
# #### Course Project
# * Come up with 5 different ideas for your course project. For each one list:
# > <p>1. Predict which coupons a customer will buy</p>
# >
# > * What data you will use : past purchase and browsing behavior data provided by Kaggle
# >
# > * What the outcome is that you are trying to achieve : prediction model for the recommendation system
# >
# > * Any ideas of modelling techniques it may involve : Collaborative filtering, Bayesian
# >
#
# >> This would be a good one to try out.
#
# > <p>2. Forecast sales using store, promotion, and competitor data</p>
# >
# > * What data you will use : historical data including Sales provided by Kaggle
# >
# >  * What the outcome is that you are trying to achieve : prediction model for 6 weeks of daily sales for 1,115 stores to create effective staff schedules that increase productivity and motivation.
# >
# >  * Any ideas of modelling techniques it may involve : Linear Regression
#
# >> Another good one to try out.
#
# > <p>3. Predict annual restraurant sales based on objective measurements</p>
# >
# > * What data you will use : open date, location, city type, and three categories of obfuscated data: Demographic data, Real estate data, and Commercial data in 137 restaurants provided by Kaggle
# >
# > * What the outcome is that you are trying to achieve : a mathematical model to increase the effectiveness of investments in new restaurant sites
# >
# > * Any ideas of modelling techniques it may involve : k-mean clustering, Principal Component Analysis, k-nearest neighbours
#
# > <p>4. Predict which shoppers will become repeat buyers</p>
# >
# >   * What data you will use : 350 million rows of completely anonymised transactional data from over 300,000 shoppers provided by Kaggle
# >
# >   * What the outcome is that you are trying to achieve : prediction model to know which shoppers will become repeat buyers
# >
# >   * Any ideas of modelling techniques it may involve : Decision Tree, Logistic Regression
# >
# > <p>5. Predict the online sales of a consumer product based on a data set of product features</p>
# >
# >   * What data you will use : monthly online sales, advertising campaign,  data provided by Kaggle
# >
# >   * What the outcome is that you are trying to achieve : prediction model for monthly online sales of a product
# >
# >   * Any ideas of modelling techniques it may involve : Linear Regression
#
# >> All these ideas are great to try out. Did you have any other ideas other than kaggle competitions? It's ok if not, these are great to start with as they are nicely defined problems.
#
# **Instructions: copy this file and append your name in the filename, e.g. Homework1_ian_hansel.ipynb.
# Then commit this in your local repository, push it to your github account and create a pull request so I can see your work. Remeber if you get stuck to look at the slides going over Fork, Clone, Commit, Push and Pull request.**

# %% [markdown]
# # Exercise Four - Movie Lens Data
# > [nakatas/SYD_DAT_4/labs/Week 1/](https://github.com/nakatas/SYD_DAT_4/blob/master/labs/Week%201/Lab%201%20-%20Pandas.ipynb)

# %%
# for each occupation in 'users', count the number of occurrences

# for each occupation, calculate the mean age

# for each occupation, calculate the minimum and maximum ages

# for each combination of occupation and gender, calculate the mean age

# randomly sample a DataFrame

# detect duplicate users
