# %% [markdown]
# # SYD DAT 5 Lab 1 - Git and Markdown
#
# ##Homework:
#
# #### Setup
# * Resolve any installation issues before next class.
# * Make sure you have a github profile and created a repo
# * Clone the class repo (this one!)
# * Review this [code](../labs/Week 1/00_python_refresher.py) for a recap of some Python basics.
#
# #### Communication
# * Read [Analyzing the Analyzers](http://cdn.oreillystatic.com/oreilly/radarreport/0636920029014/Analyzing_the_Analyzers.pdf) for a useful look at the different types of data scientists. Write down 5 key points you took away from the article
#     ##### 5 Key Points
#         * Excessive hype leads people to expect miracles, and miracle workers; and lack of awareness about the variety of data scientists leads organizations to waste effort when trying to find talent.
#         * Data Businesspeople are those that are more fosucd on the organization and how data projects yield profit.
#         * Data Creatives are the broadest of data scientists.
#         * Data Developers are people focused on the technical problem of managind Data.
#         * Data Researchers mostly come from academic researhc in the physical or social sciences or in statistics.
#
#
# * Read about some [Markdown Techniques](http://daringfireball.net/projects/markdown/syntax)
#     ##### Done
#
#
# * Write a summary of a chapter of [The Data Science Handbook](http://www.thedatasciencehandbook.com/) in Markdown and submit a pull request in the Lab Directory
#     ##### Summary of 2nd capter of the Data Science Handbook
#         * Five years is a long time. If you think back five years, data science barely existed, and it’s still evolving rapidly
#         * I do believe that data gives people the power to make better decisions, so the more people who have access to it, the better.
#         * A data scientist is someone who sits down with a question and gathers some data to answer it, or someone who starts with a data set and asks questions to learn more about it. They do some math, write some code, do the analysis, and then come to a conclusion
#         * Creating a story that’s compelling and exciting for people, while still respecting the truth of the data, is hard to do
#         * It’s like art. You’re trying to take a really intense emotion or complex phenomenon and express it in a way that people will understand intuitively.
#         * I want to know that they’re capable of thinking about what the data set is and coming up with ideas on their own for what they would like to see
#         * Another question I ask sometimes is, what is the most evil thing that could be done with this?
#
# #### Programming
# * Complete the lab from class and the additional Exercise below
#         #### Done
#
# #### Course Project
# * Come up with 5 different ideas for your course project. For each one list:
#   * Overview of your idea
#       Work with one of the following data sets
#           * History of Baseball data set and answer the questions suggested on Kaggle
#           * How ISIS Uses Twitter
#           * Work with IMDB and Movie Lens data
#           * Speed Dating Experiment
#           * Brain imaging data (fMRI)
#
#   * What data you will use, and how you will collect it
#       * Kaggle
#       * IMDB and Movie Lens
#
#   * What the outcome is that you are trying to achieve
#       * I am trying to predict behaviour or answer predicitve type questions.
#
#   * Any ideas of modelling techniques it may involve
#       * No ideas yet of modelling techniques involved.
#
# **Instructions: copy this file and append your name in the filename, e.g. Homework1_ian_hansel.ipynb.
# Then commit this in your local repository, push it to your github account and create a pull request so I can see your work. Remeber if you get stuck to look at the slides going over Fork, Clone, Commit, Push and Pull request.**

# %% [markdown]
# ## Exercise Four - Movie Lens Data

# %%
# import pandas
import pandas as pd

# read 'u.user' into 'users'
# I placed 'u.user' into the homework folder
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
users = pd.read_table('u.user', sep='|', header=None, names=user_cols, index_col='user_id', dtype={'zip_code':str})

# for each occupation in 'users', count the number of occurrences
users.occupation.value_counts()

# for each occupation, calculate the mean age
users.groupby('occupation')['age'].mean()

# for each occupation, calculate the minimum and maximum ages
users.groupby('occupation')['age'].agg(['min','max'])

# for each combination of occupation and gender, calculate the mean age
users.groupby(['occupation','gender'])['age'].mean()

# randomly sample a DataFrame
users.sample(5)

# detect duplicate users
users.duplicated()
# Out:
# user_id
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
#        ...
# 914    False
# 915    False
# 916    False
# 917    False
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# 923    False
# 924    False
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932    False
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# 943    False
# dtype: bool
