# %% [markdown]
# # Introduction to Linear Regression
#
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", )

# %%
# Summarise the data
house_data.describe()
# Out:
#        Unnamed: 0           Price       Bath  CrimeIndex  MinutesToLoop  \
# count  219.000000      219.000000  70.000000  219.000000     219.000000
# mean   109.000000   483431.050228   2.271429    4.663607       9.698630
# std     63.364028   400124.919077   0.883364    1.418146       2.898995
# min      0.000000    24500.000000   1.000000    1.090000       6.000000
# 25%     54.500000   319000.000000   2.000000    3.940000       8.000000
# 50%    109.000000   390000.000000   2.000000    4.930000       9.000000
# 75%    163.500000   512500.000000   3.000000    5.580000      10.000000
# max    218.000000  3686000.000000   4.000000    8.080000      22.000000
#
#        MilesToLake         Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# count   219.000000  219.000000   219.000000     219.000000   219.000000
# mean      3.420411   29.424658   873.200913     699.977169    49.197717
# std       0.352522   49.155880  1392.893683    1175.278922    18.554525
# min       2.770000    0.000000     0.000000       0.000000    16.700000
# 25%       3.150000    0.000000     0.000000       0.000000    36.100000
# 50%       3.400000    0.000000     0.000000       0.000000    50.000000
# 75%       3.685000   41.000000  2614.000000    1344.000000    59.500000
# max       4.200000  131.000000  7405.000000    6422.000000    93.900000
#
#        EstimatedPrice
# count      219.000000
# mean    486219.119635
# std     397858.185948
# min      28836.500000
# 25%     307448.750000
# 50%     391980.000000
# 75%     532475.000000
# max    3973508.000000

# %%
# Remove the first column that's an index
house_data = house_data.drop('Unnamed: 0', 1)

# %%
# Look for any linear correlations in the data
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# Bath           -0.039220    -0.029979       0.698526    -0.047992
# CrimeIndex     -0.036644    -0.008807       0.070952    -0.100256
# MinutesToLoop  -0.023820    -0.053292      -0.032437    -0.196728
# MilesToLake    -0.047087     0.006240      -0.046517    -0.205966
# Age             1.000000     0.716774       0.645147    -0.029953
# LotSizeSqft     0.716774     1.000000       0.828598    -0.055458
# HouseSizeSqft   0.645147     0.828598       1.000000    -0.023378
# SchoolIndex    -0.029953    -0.055458      -0.023378     1.000000
# EstimatedPrice  0.255628     0.454939       0.471783    -0.073825
#
#                 EstimatedPrice
# Price                 0.983784
# Bath                  0.105632
# CrimeIndex            0.122793
# MinutesToLoop        -0.034185
# MilesToLake          -0.082604
# Age                   0.255628
# LotSizeSqft           0.454939
# HouseSizeSqft         0.471783
# SchoolIndex          -0.073825
# EstimatedPrice        1.000000

# %%
# Plot the data
pd.scatter_matrix(house_data, figsize=(25,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e8e1590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121775b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121ef18d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122036d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122040750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1220cc410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122230ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1222a9c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122310190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122388110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1223d0d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12257fd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122603b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d443dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122668050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1226b0910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12303fa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1230c2890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12312f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1231b3790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1232186d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12329b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123404250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12348d350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12350f1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123573c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1235f6a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12375aad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1237dea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1237eced0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1240d08d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124152750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1241b7950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1243397d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1243a44d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12442c5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1244b0450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124513e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124596d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1245fbd50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12477ccd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1247b6e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12496fb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1249f19d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124b56bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124bdaa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124c43750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124ccc850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124e506d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124ebe150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x124f33f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124f8ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12511af50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1251630d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12520fdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125292c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1225236d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125359ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125375b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12554c510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1255cf550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125633c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1256b6b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12571b8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12579d850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1257d8990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1258906d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125a13550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125a77750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125af95d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x125c642d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125ceb3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125d71250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125dd1c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125e57b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125ebcb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12603dad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12604ce90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126230950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1262b37d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1263169d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12639c850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126403550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12648d650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265114d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126572f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265f5d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12675add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267ddd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126916e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1269cfbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126a53a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126ab6c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126b3aad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126ba17d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126d2d8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126daf750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126e201d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126ea6050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126f08090>]], dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
# - What looks to be affecting house prices from our initial inspection?
# - What is the type of relationship in those variables affecting price?

# %%
# create a fitted model in one line
#lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft - Age', data=house_data).fit()
lm = smf.ols(formula='Price ~ 1+Bath + HouseSizeSqft - Age', data=house_data).fit()

# print the coefficients
lm.params

# intercept term is an interaction between zero factors.
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 -28995.66*3 + 133*350
# Out:
# 467873.02

# %%
lm.summary()

# It's quite important to check, especially R-squared.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Mon, 04 Apr 2016   Prob (F-statistic):              0.269
# Time:                        19:45:17   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016      9.89e+04  9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803     -2.61e+05  2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187       -66.297   332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Let's try just the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Mon, 04 Apr 2016   Prob (F-statistic):          6.25e-164
# Time:                        19:51:56   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758     -1.28e+04  1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000         0.965     1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([   30901.56354902,  3933717.48261279])

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# then, plot the least squares line
plt.plot(X_new, preds, c='red', linewidth=2)

# %%
# Try selecting different variables or combinations of variables. Can you get a better fit?
# create a fitted model in one line
#lm = smf.ols(formula='Price ~ CrimeIndex + SchoolIndex', data=house_data).fit()
lm = smf.ols(formula='Price ~ SchoolIndex', data=house_data).fit()




# print the coefficients
lm.params
# Out:
# Intercept      560245.810762
# SchoolIndex     -1561.348074
# dtype: float64

# %%
#400193.728855 + 31752.609624 - 1318.036383
560245.810762 -1561.348074
# Out:
# 558684.462688

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
X_new = pd.DataFrame({'SchoolIndex': [house_data.SchoolIndex.min(), house_data.SchoolIndex.max()]})
X_new.head()

preds = lm.predict(X_new)
preds

# first, plot the observed data
house_data.plot(kind='scatter', x='SchoolIndex', y='Price')

# then, plot the least squares line
plt.plot(X_new, preds, c='red', linewidth=2)
