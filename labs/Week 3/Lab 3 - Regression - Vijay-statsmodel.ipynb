# %% [markdown]
# # Introduction to Linear Regression
#
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", )

# %%
house_data.head(10)
# Out:
#    Unnamed: 0                             Address Neighborhood  \
# 0           0   2111 W Division St #5, Chicago IL  Wicker Park
# 1           1     1520 W Walton St #2, Chicago IL  Wicker Park
# 2           2        2047 W Thomas St, Chicago IL  Wicker Park
# 3           3  1735 N Paulina St #314, Chicago IL  Wicker Park
# 4           4        1634 W Beach Ave, Chicago IL  Wicker Park
# 5           5     1634 W Wabansia Ave, Chicago IL  Wicker Park
# 6           6      1440 N Wood St #2F, Chicago IL  Wicker Park
# 7           7      1137 N Wood St #F2, Chicago IL  Wicker Park
# 8           8         1418 N Bell Ave, Chicago IL  Wicker Park
# 9           9     1308 N Bosworth Ave, Chicago IL  Wicker Park
#
#             HouseType   Price  Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# 0               Condo  390000   NaN        2.59              9         3.91
# 1               Condo  320500   NaN        4.10              7         3.02
# 2   Multi-Family Home  620000     4        2.09              9         3.84
# 3               Condo  318000   NaN        2.40              9         2.90
# 4   Multi-Family Home  477000     2        4.63              9         2.96
# 5  Single-Family Home  695000     2        1.40              8         2.86
# 6               Condo  242500   NaN        5.38              9         3.22
# 7               Condo  477500   NaN        4.18              8         3.39
# 8   Multi-Family Home  466000     2        4.93             10         4.02
# 9   Multi-Family Home  435000     2        4.75              8         2.89
#
#    Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# 0    0            0              0         36.2        335790.0
# 1    0            0              0         91.7        376908.0
# 2   94         3049           3492         36.2        629300.0
# 3    0            0              0         50.0        297330.0
# 4   31         2614           1840         78.9        463644.0
# 5   23         2614           1628         50.0        813150.0
# 6    0            0              0         69.4        196667.5
# 7    0            0              0         59.5        445030.0
# 8  121         3049           1344         16.7        538696.0
# 9  119         3485           1760         40.0        463275.0

# %%
# Summarise the data
house_data.describe()
# Out:
#        Unnamed: 0           Price       Bath  CrimeIndex  MinutesToLoop  \
# count  219.000000      219.000000  70.000000  219.000000     219.000000
# mean   109.000000   483431.050228   2.271429    4.663607       9.698630
# std     63.364028   400124.919077   0.883364    1.418146       2.898995
# min      0.000000    24500.000000   1.000000    1.090000       6.000000
# 25%     54.500000   319000.000000   2.000000    3.940000       8.000000
# 50%    109.000000   390000.000000   2.000000    4.930000       9.000000
# 75%    163.500000   512500.000000   3.000000    5.580000      10.000000
# max    218.000000  3686000.000000   4.000000    8.080000      22.000000
#
#        MilesToLake         Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# count   219.000000  219.000000   219.000000     219.000000   219.000000
# mean      3.420411   29.424658   873.200913     699.977169    49.197717
# std       0.352522   49.155880  1392.893683    1175.278922    18.554525
# min       2.770000    0.000000     0.000000       0.000000    16.700000
# 25%       3.150000    0.000000     0.000000       0.000000    36.100000
# 50%       3.400000    0.000000     0.000000       0.000000    50.000000
# 75%       3.685000   41.000000  2614.000000    1344.000000    59.500000
# max       4.200000  131.000000  7405.000000    6422.000000    93.900000
#
#        EstimatedPrice
# count      219.000000
# mean    486219.119635
# std     397858.185948
# min      28836.500000
# 25%     307448.750000
# 50%     391980.000000
# 75%     532475.000000
# max    3973508.000000

# %%
# Remove the first column that's an index
house_data = house_data.drop('Unnamed: 0', 1)

# %%
# Look for any linear correlations in the data
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# Bath           -0.039220    -0.029979       0.698526    -0.047992
# CrimeIndex     -0.036644    -0.008807       0.070952    -0.100256
# MinutesToLoop  -0.023820    -0.053292      -0.032437    -0.196728
# MilesToLake    -0.047087     0.006240      -0.046517    -0.205966
# Age             1.000000     0.716774       0.645147    -0.029953
# LotSizeSqft     0.716774     1.000000       0.828598    -0.055458
# HouseSizeSqft   0.645147     0.828598       1.000000    -0.023378
# SchoolIndex    -0.029953    -0.055458      -0.023378     1.000000
# EstimatedPrice  0.255628     0.454939       0.471783    -0.073825
#
#                 EstimatedPrice
# Price                 0.983784
# Bath                  0.105632
# CrimeIndex            0.122793
# MinutesToLoop        -0.034185
# MilesToLake          -0.082604
# Age                   0.255628
# LotSizeSqft           0.454939
# HouseSizeSqft         0.471783
# SchoolIndex          -0.073825
# EstimatedPrice        1.000000

# %%
# Plot the data
pd.scatter_matrix(house_data, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x108edd790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c04d410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c0bbfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c14a210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c196b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c322fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c3a5e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c513b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c597c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c5fac90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c67be90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c61e290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c76dd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c7f0c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c961350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c9e4210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cb48290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cbc9250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cd033d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cdbc350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10ce3f210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ce8e050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d003dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d034690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d101b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d184b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d1eaa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d26ca10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d2d1710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d4536d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10d4d7590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d5447d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d5c7690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d72d610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d7af4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d818210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d89f350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d925210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d986c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10da0ab50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10da6cbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10daf0b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10dafef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10dce1a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10de65950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10decaad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10df4d990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10dfb66d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e034050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e0aca90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10e21b990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e2a9110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e2f6b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e383b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e4079d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e475c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e4f7ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e65da50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e6de910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e745650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10e7d1790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e854650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e8c3110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ea39f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10eaad050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ec20fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ec66190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ed13ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ed96d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10edfbf10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10ee7cdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10eee4b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ef6fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10eff2b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f14b150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f1cf890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f326d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f3c0210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f3f9390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f4a5dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10f528c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f58dc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f710ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f778810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110001950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110084810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1100f62d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11017a190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1101de210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1103601d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x110399350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1104520d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1104c7f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11053c110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1105aff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110718cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1107a1e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111024cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111092790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111216650>]], dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
# - What looks to be affecting house prices from our initial inspection?
# - What is the type of relationship in those variables affecting price?

# %%
# create a fitted model in one line
lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 - 28995.66*3 + 133*350
# Out:
# 467873.02

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Sat, 09 Apr 2016   Prob (F-statistic):              0.269
# Time:                        18:46:20   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016      9.89e+04  9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803     -2.61e+05  2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187       -66.297   332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Let's try just the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Sat, 09 Apr 2016   Prob (F-statistic):          6.25e-164
# Time:                        18:47:20   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758     -1.28e+04  1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000         0.965     1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([   30901.56354902,  3933717.48261279])

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# then, plot the least squares line
plt.plot(X_new, preds, c='red', linewidth=2)

# %%
# Try selecting different variables or combinations of variables. Can you get a better fit?
lm_vj = smf.ols(formula='Price ~ CrimeIndex + Age + LotSizeSqft + HouseSizeSqft',
       data=house_data).fit()
lm_vj.params
# Out:
# Intercept        250711.794550
# CrimeIndex        26534.937639
# Age               -1542.162536
# LotSizeSqft          97.291161
# HouseSizeSqft        99.136948
# dtype: float64

# %%
## Predict the house price of a 2 bathroom, Crime Index = 2.09, Age = 34, LotSizeSqft = 3000, HouseSizeSqft = 3400
250711.794550 + 2.09*26534.937639 + 34*-1542.162536 + 3000*97.291161 + 3400*99.136948
# Out:
# 882675.39419151

# %%
lm_vj.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     17.75
# Date:                Sat, 09 Apr 2016   Prob (F-statistic):           1.34e-12
# Time:                        18:48:15   Log-Likelihood:                -3103.9
# No. Observations:                 219   AIC:                             6218.
# Df Residuals:                     214   BIC:                             6235.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      2.507e+05   8.38e+04      2.990      0.003      8.55e+04  4.16e+05
# CrimeIndex     2.653e+04   1.69e+04      1.569      0.118     -6801.837  5.99e+04
# Age           -1542.1625    698.885     -2.207      0.028     -2919.742  -164.583
# LotSizeSqft      97.2912     33.711      2.886      0.004        30.843   163.740
# HouseSizeSqft    99.1369     36.734      2.699      0.008        26.730   171.544
# ==============================================================================
# Omnibus:                      302.291   Durbin-Watson:                   1.330
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24563.320
# Skew:                           6.184   Prob(JB):                         0.00
# Kurtosis:                      53.388   Cond. No.                     7.47e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
