# %% [markdown]
# # Restaurant Revenue Prediction

# %% [markdown]
# Predict annual restaurant sales based on objective measurements
#
# https://www.kaggle.com/c/restaurant-revenue-prediction

# %%
import pandas as pd

pd.read_table("data/train.csv")
# Out:
#     Id,Open Date,City,City Group,Type,P1,P2,P3,P4,P5,P6,P7,P8,P9,P10,P11,P12,P13,P14,P15,P16,P17,P18,P19,P20,P21,P22,P23,P24,P25,P26,P27,P28,P29,P30,P31,P32,P33,P34,P35,P36,P37,revenue
# 0    0,07/17/1999,İstanbul,Big Cities,IL,4,5.0,4.0,...
# 1    1,02/14/2008,Ankara,Big Cities,FC,4,5.0,4.0,4....
# 2    2,03/09/2013,Diyarbakır,Other,IL,2,4.0,2.0,5.0...
# 3    3,02/02/2012,Tokat,Other,IL,6,4.5,6.0,6.0,4,4,...
# 4    4,05/09/2009,Gaziantep,Other,IL,3,4.0,3.0,4.0,...
# 5    5,02/12/2010,Ankara,Big Cities,FC,6,6.0,4.5,7....
# 6    6,10/11/2010,İstanbul,Big Cities,IL,2,3.0,4.0,...
# 7    7,06/21/2011,İstanbul,Big Cities,IL,4,5.0,4.0,...
# 8    8,08/28/2010,Afyonkarahisar,Other,IL,1,1.0,4.0...
# 9    9,11/16/2011,Edirne,Other,IL,6,4.5,6.0,7.5,6,4...
# 10   10,08/09/2013,Kocaeli,Other,FC,9,6.0,6.0,6.0,4...
# 11   11,05/22/2012,İstanbul,Big Cities,IL,2,4.0,4.0...
# 12   12,02/28/2013,Ankara,Big Cities,IL,2,2.0,4.0,4...
# 13   13,10/16/2010,İstanbul,Big Cities,FC,4,5.0,4.0...
# ...

# %%
restaurants_cols = ['Id', 'Open Date', 'City', 'City Group', 'Type','P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11','P12','P13','P14','P15','P16','P17','P18','P19','P20','P21','P22','P23','P24','P25','P26','P27','P28','P29','P30','P31','P32','P33','P34','P35','P36','P37','revenue']
restaurants = pd.read_table('data/train.csv', sep=',', header=None, names=restaurants_cols, index_col='Id')

# %%
restaurants.shape             # number of rows and columns
restaurants.values            # underlying numpy array
restaurants.info()            # concise summary (including memory usage)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138 entries, Id to 136
# Data columns (total 42 columns):
# Open Date     138 non-null object
# City          138 non-null object
# City Group    138 non-null object
# Type          138 non-null object
# P1            138 non-null object
# P2            138 non-null object
# P3            138 non-null object
# P4            138 non-null object
# P5            138 non-null object
# P6            138 non-null object
# P7            138 non-null object
# P8            138 non-null object
# P9            138 non-null object
# P10           138 non-null object
# P11           138 non-null object
# P12           138 non-null object
# P13           138 non-null object
# P14           138 non-null object
# P15           138 non-null object
# P16           138 non-null object
# P17           138 non-null object
# P18           138 non-null object
# P19           138 non-null object
# P20           138 non-null object
# ...

# %%
restaurants.revenue
# Out:
# Id
# Id        revenue
# 0       5653753.0
# 1       6923131.0
# 2       2055379.0
# 3       2675511.0
# 4       4316715.0
# 5       5017319.0
# 6       5166635.0
# 7       4491607.0
# 8       4952497.0
# 9       5444227.0
# 10      3745135.0
# 11      5161370.0
# 12      1734634.0
# 13      4807746.0
# 14      1999097.0
# 15      3218918.0
# 16     19696939.0
# 17      8213524.0
# 18      5337526.0
# 19      2021934.0
# 20      5525735.0
# 21      1149870.0
# 22      3956086.0
# 23      2999068.0
# 24      8904084.0
# 25      3778621.0
# 26      2267425.0
# 27      5435276.0
# 28      4705945.0
#           ...
# 107     3248660.0
# 108     3570392.0
# 109     4219263.0
# 110     2954086.0
# 111     2993069.0
# 112     3784230.0
# 113     2097022.0
# 114     4155435.0
# 115     4882985.0
# 116     8894598.0
# 117     2018785.0
# 118     1847826.0
# 119     3780019.0
# 120     4067566.0
# 121     3445076.0
# 122     4286645.0
# 123     4263629.0
# 124     3810007.0
# ...
