# %%
#libraries
import pandas as pd

# %%
mydata = pd.read_excel('ALL.xlsx', sheetname ='FINAL_DATA')

# %%
mydata.shape
# Out:
# (3994, 30)

# %%
#head of the data
mydata.head(n=4)

# %%
mydata.describe
# Out:
# <bound method DataFrame.describe of      ASX Code                             Company Name  \
# 0         1AG                          Alterra Limited
# 1         1AG                          Alterra Limited
# 2         1AL             OneAll International Limited
# 3         1AL             OneAll International Limited
# 4         1PG                           1-Page Limited
# 5         1PG                           1-Page Limited
# 6         1st                    1st Available Limited
# 7         1st                    1st Available Limited
# 8         3PL                      3P Learning Limited
# 9         3PL                      3P Learning Limited
# 10        4DS                       4DS Memory Limited
# 11        4DS                       4DS Memory Limited
# 12        88E                        88 Energy Limited
# 13        88E                        88 Energy Limited
# 14        8CO                              8Common Ltd
# ...
