# %%
immport pandas as pd
# Out:
#   File "<ipython-input-1-19ca184bd02a>", line 1
#     immport pandas as pd
#                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv('data/sydtrains.csv')

# %%
df.describe()
# Out:
#               YEAR  IN_0200_0600  OUT_0200_0600  IN_0600_0930  OUT_0600_0930  \
# count  3367.000000   3367.000000    3367.000000   3367.000000    3367.000000
# mean   2009.013959     47.528958      29.364419   1061.749332    1010.986041
# std       3.164360     96.815978      78.484683   1480.814320    4061.525304
# min    2004.000000      0.000000       0.000000      0.000000       0.000000
# 25%    2006.000000     10.000000       0.000000     90.000000      20.000000
# 50%    2009.000000     20.000000      10.000000    460.000000     140.000000
# 75%    2012.000000     50.000000      20.000000   1430.000000     530.000000
# max    2014.000000    940.000000     920.000000  10630.000000   43210.000000
#
#        IN_0930_1500  OUT_0930_1500  IN_1500_1830  OUT_1500_1830  IN_1830_0200  \
# count   3367.000000    3367.000000   3367.000000    3367.000000   3367.000000
# mean     712.803683     727.635878   1093.415503    1036.587467    324.359964
# ...

# %%
df.head()
# Out:
#           LINE       STATION  YEAR SURVEY_DATE_USED WHETHER_SURVEYED  \
# 0          CBD       Central  2014        6/05/2014              Yes
# 1          CBD     Town Hall  2014        7/05/2014              Yes
# 2          CBD       Wynyard  2014       20/05/2014              Yes
# 3      Western    Parramatta  2014       19/11/2014              Yes
# 4  North Shore  North Sydney  2014       19/08/2014              Yes
#
#    IN_0200_0600  OUT_0200_0600  IN_0600_0930  OUT_0600_0930  IN_0930_1500  \
# 0           940            920         10390          42070         21400
# 1           880            880          6380          43210         16930
# 2           590            570          4710          39620          9200
# 3           660            330          7790          13700          7400
# 4           270            270          2340          18340          4450
#
#    OUT_0930_1500  IN_1500_1830  OUT_1500_1830  IN_1830_0200  OUT_1830_0200  \
# ...

# %%
df.YEAR == 2014
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 3337    False
# 3338    False
# 3339    False
# 3340    False
# 3341    False
# 3342    False
# 3343    False
# 3344    False
# 3345    False
# 3346    False
# 3347    False
# 3348    False
# 3349    False
# 3350    False
# 3351    False
# 3352    False
# 3353    False
# 3354    False
# 3355    False
# 3356    False
# 3357    False
# 3358    False
# 3359    False
# 3360    False
# 3361    False
# 3362    False
# 3363    False
# 3364    False
# 3365    False
# 3366    False
# Name: YEAR, dtype: bool

# %%
df = pd.read_csv('data/sydtrains.csv', index_col=1)

# %%
df.head()
# Out:
#                      LINE  YEAR SURVEY_DATE_USED WHETHER_SURVEYED  \
# STATION
# Central               CBD  2014        6/05/2014              Yes
# Town Hall             CBD  2014        7/05/2014              Yes
# Wynyard               CBD  2014       20/05/2014              Yes
# Parramatta        Western  2014       19/11/2014              Yes
# North Sydney  North Shore  2014       19/08/2014              Yes
#
#               IN_0200_0600  OUT_0200_0600  IN_0600_0930  OUT_0600_0930  \
# STATION
# Central                940            920         10390          42070
# Town Hall              880            880          6380          43210
# Wynyard                590            570          4710          39620
# Parramatta             660            330          7790          13700
# North Sydney           270            270          2340          18340
#
#               IN_0930_1500  OUT_0930_1500  IN_1500_1830  OUT_1500_1830  \
# STATION
# ...

# %%
df2014 = df[df.YEAR == 2014]

# %%
df2014.IN_0200_0600.idxmin()
# Out:
# 'Green Square'

# %%
df2014.IN_0200_0600.sum()
# Out:
# 16060

# %%
df2014.IN_24_HOURS.sum()
# Out:
# '97,11089,62060,20034,96028,61025,68022,20021,88020,71020,63020,63018,29017,59016,56014,99012,87012,25011,20011,10010,91010,89010,86010,57010,0909,8509,6408,7308,6308,3508,3208,0507,8407,5207,4107,1907,0907,0706,9906,9006,7306,6906,6506,1106,0805,8905,7505,7305,6605,6605,2805,2605,0504,8004,5704,5604,5604,2904,2704,2404,1804,1104,0904,0703,9603,9003,8903,6803,7803,5903,5903,5903,5703,5503,5103,4403,3403,3103,2503,1903,1503,0503,1403,0403,0102,9502,9502,9502,8702,8202,8202,7902,7602,6602,6602,6502,6102,6002,5402,5402,4702,4602,4502,4302,4202,4102,4002,3802,3802,3802,3702,3502,3402,3102,2902,2602,2202,2102,1202,1202,0802,0802,0702,0602,0201,9101,8601,7801,7801,7201,7101,6701,6601,6401,6101,5801,5801,5601,5401,5301,5201,4801,4701,4501,4401,3701,3701,3401,3201,2901,2301,2201,1601,1401,1001,0801,0701,0601,040970970940920880870870860840840830830820770770750720680670670660660620570570560550530520500500480480460430420390380380380380370360350340330320320320320320320310300300290280280270260250
# ...

# %%
pd.read_csv?

# %%
df = pd.read_csv('data/sydtrains.csv', index_col=1, thousands=',')

# %%
df.head()
# Out:
#                      LINE  YEAR SURVEY_DATE_USED WHETHER_SURVEYED  \
# STATION
# Central               CBD  2014        6/05/2014              Yes
# Town Hall             CBD  2014        7/05/2014              Yes
# Wynyard               CBD  2014       20/05/2014              Yes
# Parramatta        Western  2014       19/11/2014              Yes
# North Sydney  North Shore  2014       19/08/2014              Yes
#
#               IN_0200_0600  OUT_0200_0600  IN_0600_0930  OUT_0600_0930  \
# STATION
# Central                940            920         10390          42070
# Town Hall              880            880          6380          43210
# Wynyard                590            570          4710          39620
# Parramatta             660            330          7790          13700
# North Sydney           270            270          2340          18340
#
#               IN_0930_1500  OUT_0930_1500  IN_1500_1830  OUT_1500_1830  \
# STATION
# ...

# %%
df2014 = df[df.YEAR == 2014]

# %%
df2014.IN_24_HOURS.sum()
# Out:
# 1114510
